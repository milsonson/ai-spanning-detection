# %%
import numpy as np
print("NumPy version:", np.__version__)
arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Sum:", np.sum(arr))
# Out:
# NumPy version: 2.3.3
# Array: [1 2 3 4 5]
# Sum: 15
